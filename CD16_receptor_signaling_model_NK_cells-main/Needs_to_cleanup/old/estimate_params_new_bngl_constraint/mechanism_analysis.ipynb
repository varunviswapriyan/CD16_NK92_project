# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load and process data
directory = "gamma_runs/analysis/bng_output_"
data = [pd.read_csv(f"{directory}{i}/model.gdat", sep="\t", comment='#') for i in range(3)]

# Define proper column labels
column_labels = ['PZAP_total', 'pSYK_total', 'pSYK_bound', 'pSYK_free', 
                'PZAP_bound', 'PZAP_free', 'bound_SHP1', 'gamma_bound', 'bound_ZAP','bound_SYK','bound_pSYK_uSYK',
                'adaptor_free', 'ligand_bound_complexes']

# Stack data and compute means
stacked = np.stack([df.values for df in data])
means = np.mean(stacked, axis=0)
time = data[0].iloc[:, 0]

# Plot all columns (skip time column) - Gamma condition with unique colors
plt.figure(figsize=(10, 6))
colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4', '#FFEAA7', '#DDA0DD', '#98D8C8', '#F7DC6F', '#BB8FCE', '#85C1E9', '#F8C471', '#82E0AA', '#F1948A']
for i, label in enumerate(column_labels):
    plt.plot(time, means[:, i+1]/(602.0*25.0), label=label, color=colors[i % len(colors)], linewidth=2)

plt.xlabel("Time (s)", fontsize=12)
plt.ylabel("Concentration (μM)", fontsize=12)
plt.title("Mean Species Concentrations - Gamma Condition", fontsize=14)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Load and process data
#       2 directory = "gamma_runs/analysis/bng_output_"
# ----> 3 data = [pd.read_csv(f"{directory}{i}/model.gdat", sep="\t", comment='#') for i in range(3)]
#       5 # Define proper column labels
#       6 column_labels = ['PZAP_total', 'pSYK_total', 'pSYK_bound', 'pSYK_free',
#       7                 'PZAP_bound', 'PZAP_free', 'bound_SHP1', 'gamma_bound', 'bound_ZAP','bound_SYK','bound_pSYK_uSYK',
#       8                 'adaptor_free', 'ligand_bound_complexes']
#
# Cell In[2], line 3, in <listcomp>(.0)
#       1 # Load and process data
#       2 directory = "gamma_runs/analysis/bng_output_"
# ----> 3 data = [pd.read_csv(f"{directory}{i}/model.gdat", sep="\t", comment='#') for i in range(3)]
#       5 # Define proper column labels
#       6 column_labels = ['PZAP_total', 'pSYK_total', 'pSYK_bound', 'pSYK_free',
#       7                 'PZAP_bound', 'PZAP_free', 'bound_SHP1', 'gamma_bound', 'bound_ZAP','bound_SYK','bound_pSYK_uSYK',
#       8                 'adaptor_free', 'ligand_bound_complexes']
#
# File ~/.conda/envs/CD16_sig/lib/python3.8/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/.conda/envs/CD16_sig/lib/python3.8/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/.conda/envs/CD16_sig/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/.conda/envs/CD16_sig/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/.conda/envs/CD16_sig/lib/python3.8/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'gamma_runs/analysis/bng_output_0/model.gdat'

# %%
# Load and process data
directory = "zeta_runs/analysis/bng_output_"
data = [pd.read_csv(f"{directory}{i}/model.gdat", sep="\t", comment='#') for i in range(3)]

# Define proper column labels
column_labels = ['PZAP_total', 'pSYK_total', 'pSYK_bound', 'pSYK_free', 
                'PZAP_bound', 'PZAP_free', 'bound_SHP1', 'gamma_bound', 'bound_ZAP','bound_SYK','bound_pSYK_uSYK',
                'adaptor_free', 'ligand_bound_complexes']

# Stack data and compute means
stacked = np.stack([df.values for df in data])
means = np.mean(stacked, axis=0)
time = data[0].iloc[:, 0]

# Plot all columns (skip time column) - Zeta condition with unique colors
plt.figure(figsize=(10, 6))
colors = ['#2E86AB', '#A23B72', '#F18F01', '#C73E1D', '#6A994E', '#9A031E', '#FB8500', '#8ECAE6', '#219EBC', '#023047', '#FFB3BA', '#BFDBFE', '#FDE68A']
for i, label in enumerate(column_labels):
    plt.plot(time, means[:, i+1]/(602.0*25), label=label, color=colors[i % len(colors)], linewidth=2)

plt.xlabel("Time (s)", fontsize=12)
plt.ylabel("Concentration (μM)", fontsize=12)
plt.title("Mean Species Concentrations - Zeta Condition", fontsize=14)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Load and process data
directory = "mixed_runs/analysis/bng_output_"
data = [pd.read_csv(f"{directory}{i}/model.gdat", sep="\t", comment='#') for i in range(3)]

# Define proper column labels
column_labels = ['PZAP_total', 'pSYK_total', 'pSYK_bound', 'pSYK_free', 
                'PZAP_bound', 'PZAP_free', 'bound_SHP1', 'gamma_bound', 'bound_ZAP','bound_SYK','bound_pSYK_uSYK',
                'adaptor_free', 'ligand_bound_complexes']

# Stack data and compute means
stacked = np.stack([df.values for df in data])
means = np.mean(stacked, axis=0)
time = data[0].iloc[:, 0]

# Plot all columns (skip time column) - Mixed condition with unique colors
plt.figure(figsize=(10, 6))
colors = ['#7209B7', '#2D4A22', '#FF8500', '#C9184A', '#4361EE', '#F72585', '#4CC9F0', '#7209B7', '#560BAD', '#480CA8', '#3A0CA3', '#3F37C9', '#4361EE']
for i, label in enumerate(column_labels):
    plt.plot(time, means[:, i+1]/(602.0*25), label=label, color=colors[i % len(colors)], linewidth=2)

plt.xlabel("Time (s)", fontsize=12)
plt.ylabel("Concentration (μM)", fontsize=12)
plt.title("Mean Species Concentrations - Mixed Condition", fontsize=14)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Load data for all three conditions
directories = {
    'zeta': "zeta_runs/analysis/bng_output_",
    'mixed': "mixed_runs/analysis/bng_output_", 
    'gamma': "gamma_runs/analysis/bng_output_"
}

# Colors for each condition
colors = {'zeta': '#1f77b4', 'mixed': '#87ceeb', 'gamma': '#ff7f0e'}

# Column labels
column_labels = ['PZAP_total', 'pSYK_total', 'pSYK_bound', 'pSYK_free', 
                'PZAP_bound', 'PZAP_free', 'bound_SHP1', 'gamma_bound', 'bound_ZAP','bound_SYK','bound_pSYK_uSYK',
                'adaptor_free', 'ligand_bound_complexes']

# Load and process data for all conditions
all_data = {}
for condition, directory in directories.items():
    data = [pd.read_csv(f"{directory}{i}/model.gdat", sep="\t", comment='#') for i in range(3)]
    stacked = np.stack([df.values for df in data])
    means = np.mean(stacked, axis=0)
    time = data[0].iloc[:, 0]
    all_data[condition] = {'time': time, 'means': means}

# Create subplot for each species - Updated to 3x5 grid to accommodate all 13 species
fig, axes = plt.subplots(3, 5, figsize=(25, 15))
axes = axes.flatten()

for i, species in enumerate(column_labels):
    ax = axes[i]
    
    # Plot each condition for this species
    for condition in ['zeta', 'mixed', 'gamma']:
        time = all_data[condition]['time']
        concentration = all_data[condition]['means'][:, i+1] / (602.0 * 25.0)
        ax.plot(time, concentration, label=condition, color=colors[condition], linewidth=3)
    
    ax.set_xlabel('Time (s)', fontsize=14)
    ax.set_ylabel('Concentration (μM)', fontsize=14)
    ax.set_title(species, fontsize=16)
    ax.legend(fontsize=12)
    #ax.grid(True, alpha=0.3)
    ax.tick_params(axis='both', which='major', labelsize=12)

# Hide unused subplots (we have 13 species, so 2 empty subplots in 3x5 grid)
for j in range(len(column_labels), len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()

# Alternative: Individual plots for each species
for species_idx, species in enumerate(column_labels):
    plt.figure(figsize=(8, 6))
    
    for condition in ['zeta', 'mixed', 'gamma']:
        time = all_data[condition]['time']
        concentration = all_data[condition]['means'][:, species_idx+1] / (602.0 * 25.0)
        plt.plot(time, concentration, label=condition, color=colors[condition], linewidth=3)
    
    plt.xlabel('Time (s)', fontsize=16)
    plt.ylabel('Concentration (μM)', fontsize=16)
    plt.title(f'{species} - Comparison across conditions', fontsize=18)
    plt.legend(fontsize=14)
    #plt.grid(True, alpha=0.3)
    plt.tick_params(axis='both', which='major', labelsize=14)
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 30
#      27 axes = axes.flatten()
#      29 for i, species in enumerate(column_labels):
# ---> 30     ax = axes[i]
#      32     # Plot each condition for this species
#      33     for condition in ['zeta', 'mixed', 'gamma']:
#
# IndexError: index 10 is out of bounds for axis 0 with size 10
